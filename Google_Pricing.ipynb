# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup
import selenium

# %%
url = "https://www.google.com/search?q=asics+gel+game+8&tbm=shop"

response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html lang="en">
#  <head>
#   <title>
#    asics gel game 8 - Google Shopping
#   </title>
#   <meta content="width=device-width,maximum-scale=1.0,initial-scale=1.0,minimum-scale=0.9,user-scalable=no" name="viewport"/>
#   <meta content="address=no" name="format-detection"/>
#   <meta content="email=no" name="format-detection"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <script nonce="1+4EU7gmh1uWfKiVemPMiw==">
#    (function(){
# var a=window.performance;window.start=Date.now();a:{var b=window;if(a){var c=a.timing;if(c){var d=c.navigationStart,f=c.responseStart;if(f>d&&f<=window.start){window.start=f;b.wsrt=f-d;break a}}a.now&&(b.wsrt=Math.floor(a.now()))}}window.google=window.google||{};}).call(this);
#   </script>
#   <style>
# ...

# %%
#Pring Title
print(soup.title)
# Out:
# <title>asics gel game 8 - Google Shopping</title>

# %%
soup.findAll('div')
# Out:
# [<div class="cOl4Id"><a href="/?sa=X&amp;ved=0ahUKEwjBxqyYkvfvAhUlIbcAHQoeCdgQOwgB"><span class="V6gwVd">G</span><span class="iWkuvd">o</span><span class="cDrQ7">o</span><span class="V6gwVd">g</span><span class="ntlR9">l</span><span class="iWkuvd tJ3Myc">e</span></a></div>,
# ...

# %%
for link in soup.find_all('div'):
    print(link.get('class'))
# Out:
# ['cOl4Id']
# ['xcR77']
# ['sbc']
# ['x']
# ['sc']
# ['waUTpd', 'VtsLZc']
# ['aJp2hc']
# ['jS45xd']
# ['lnNUC']
# ['V1KQw']
# ['VGqYqb', 'hgE6tf']
# ['KZmu8e']
# ['SirUVb', 'sh-img__image']
# ['rz2LD']
# ['HUOptb']
# ['ljqwrc']
# ['sh-np__product-title', 'translate-content']
# ['hn9kf']
# ['sh-np__seller-container']
# ['U6puSd']
# ['KZmu8e']
# ['SirUVb', 'sh-img__image']
# ['rz2LD']
# ['HUOptb']
# ['ljqwrc']
# ['sh-np__product-title', 'translate-content']
# ['hn9kf']
# ['sh-np__seller-container']
# ['U6puSd']
# ['KZmu8e']
# ['SirUVb', 'sh-img__image']
# ['rz2LD']
# ['HUOptb']
# ['ljqwrc']
# ['sh-np__product-title', 'translate-content']
# ['hn9kf']
# ['sh-np__seller-container']
# ['KZmu8e']
# ['SirUVb', 'sh-img__image']
# ['rz2LD']
# ['HUOptb']
# ['ljqwrc']
# ['sh-np__product-title', 'translate-content']
# ['hn9kf']
# ['sh-np__seller-container']
# ['U6puSd']
# ['KZmu8e']
# ['SirUVb', 'sh-img__image']
# ['rz2LD']
# ['HUOptb']
# ['ljqwrc']
# ['sh-np__product-title', 'translate-content']
# ...

# %%
#soup.find_all(class_="dD8iuc")[1]
print(soup.find_all(class_="HRLxBb")[2])
print(soup.find_all(class_="HRLxBb")[2].next_element)
print(soup.find_all(class_="HRLxBb")[2].next_element.next_element)
print(soup.find_all(class_="HRLxBb")[2].next_element.next_element.next_element)
# Out:
# <span class="HRLxBb">$65.00</span>
# $65.00
#  from ASICS
# <span class="dD8iuc">+$5.00 shipping</span>

# %%
soup.find_all(class_="rgHvZc")[2]
# Out:
# <div class="rgHvZc"><a href="/url?q=https://www.asics.com/us/en-us/gel-game-8-gs/p/1044A025-400.html%3Fsize%3D6%3Futm_source%3Dgoogle%26utm_medium%3Dpla%26CAWELAID%3D120223060000762629&amp;sa=U&amp;ved=0ahUKEwjBxqyYkvfvAhUlIbcAHQoeCdgQsDwIkQE&amp;usg=AOvVaw1mLvjUQjolPjsUF67HVQHc"><b>Asics Gel Game 8</b> GS Blue/Silver Junior Shoes</a></div>

# %%
price = soup.find_all(class_="HRLxBb")

# %%
price
# Out:
# [<span class="HRLxBb">$65.00</span>,
#  <span class="HRLxBb">$74.99</span>,
#  <span class="HRLxBb">$65.00</span>,
#  <span class="HRLxBb">$80.00</span>,
#  <span class="HRLxBb">$85.49</span>,
#  <span class="HRLxBb">$59.95</span>,
#  <span class="HRLxBb">$49.95</span>,
#  <span class="HRLxBb">$65.00</span>,
#  <span class="HRLxBb">$130.39</span>,
#  <span class="HRLxBb">$65.00</span>,
#  <span class="HRLxBb">$54.95</span>,
#  <span class="HRLxBb">$85.49</span>,
#  <span class="HRLxBb">$59.94</span>,
#  <span class="HRLxBb">$89.91</span>,
#  <span class="HRLxBb">$89.91</span>,
#  <span class="HRLxBb">$99.95</span>,
#  <span class="HRLxBb">$55.99</span>,
#  <span class="HRLxBb">$14.99</span>,
#  <span class="HRLxBb">$91.51</span>,
#  <span class="HRLxBb">$111.51</span>,
#  <span class="HRLxBb">$59.95</span>]
